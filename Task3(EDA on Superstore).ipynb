# %% [markdown]
# # Grip At The Sparks Foundation Intenship
# ## Task: 3 Exploratory Data Analysis - Retail
# ### Author : Charuta U. Kulkarni.
# #### Dataset: SampleSuperstore.csv

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/Kulkarni/Desktop/SampleSuperstore.csv")

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 702.8+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(df.corr(), cmap ='summer_r' ,annot = True, cbar = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From above Heatmap we can say :
# 1. Profit and sale are Moderately correlated.
# 2. Profit and Discount are Negatively Correlated.
# 3.Quantity and Sales are less correlated

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Distrubution Plot

# %%
fig, axs = plt.subplots(ncols=2, nrows = 2, figsize = (10,10))
sns.distplot(df['Sales'], color = 'red',  ax = axs[0][0])
sns.distplot(df['Profit'], color = 'blue',  ax = axs[0][1])
sns.distplot(df['Quantity'], color = 'orange',  ax = axs[1][0])
sns.distplot(df['Discount'], color = 'grey',  ax = axs[1][1])
axs[0][0].set_title('Sales Distribution', fontsize = 20)
axs[0][1].set_title('Profit Distribution', fontsize = 20)
axs[1][0].set_title('Quantity distribution', fontsize = 20)
axs[1][1].set_title('Discount Distribution', fontsize = 20)
plt.show()
# Out:
# c:\users\kulkarni\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\kulkarni\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Plotting a Graph between Sales and Profit

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['Sales'],color='red',label='Sales',shade=True,bw=25)
sns.kdeplot(df['Profit'],color='Blue',label='Profit',shade=True,bw=25)
plt.xlim([-100,1000])
plt.legend()
# Out:
# c:\users\kulkarni\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# c:\users\kulkarni\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Pairplot to analyse each column

# %% [markdown]
# ### 1. Based on Category

# %%
sns.pairplot(df,hue = 'Category')

# %% [markdown]
# ###  3.Based on Region

# %%
sns.pairplot(df , hue = 'Region')

# %% [markdown]
# ### 4. Based on Segment

# %%
sns.pairplot(df, hue = 'Segment')

# %% [markdown]
# ## Analyzing Profit based on various aspects

# %% [markdown]
# ### 1.Based on Ship Mode

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
sns.countplot(df['Ship Mode'])
# Out:
# c:\users\kulkarni\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %%
df_shipmode = df.groupby(['Ship Mode'])['Sales','Discount','Profit'].mean()
df_shipmode
# Out:
# <ipython-input-22-fbd0236e40ae>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_shipmode = df.groupby(['Ship Mode'])['Sales','Discount','Profit'].mean()
#                      Sales  Discount     Profit
# Ship Mode
# First Class     228.497024  0.164610  31.839948
# Same Day        236.396179  0.152394  29.266591
# Second Class    236.089239  0.138895  29.535545
# Standard Class  227.583067  0.160023  27.494770

# %%
df[df['Ship Mode']=='Standard Class'].Profit.sum()
# Out:
# 164088.7875

# %%
df[df['Ship Mode']== 'First Class'].Profit.sum()
# Out:
# 48969.8399

# %%
df[df['Ship Mode'] == 'Second Class'].Profit.sum()
# Out:
# 57446.63540000001

# %%
df[df['Ship Mode']== 'Same Day'].Profit.sum()
# Out:
# 15891.7589

# %%
df_shipmode.plot.pie(subplots = True,labels = df_shipmode.index,autopct = '%1.2f%%',figsize = (18,20))
# Out:
# c:\users\kulkarni\appdata\local\programs\python\python38-32\lib\site-packages\pandas\plotting\_matplotlib\core.py:1547: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %% [markdown]
# #### Profit is more in first class
# #### Discount is more in First class
# #### sales are more in same day

# %% [markdown]
# ## Analyzing Profit Based on Segments

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
sns.countplot(df['Segment'])
# Out:
# c:\users\kulkarni\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %%
df[df['Segment'] == 'Consumer'].Profit.sum()
# Out:
# 134119.2092

# %%
df[df['Segment']=='Corporate'].Profit.sum()
# Out:
# 91979.13399999999

# %%
df[df['Segment'] == 'Home Office'].Profit.sum()
# Out:
# 60298.678499999995

# %%
df[df['Segment']=='Consumer'].Profit.sum()/len(df[df['Segment']=='Consumer'])
# Out:
# 25.8368732806781

# %%
df_segment = df.groupby('Segment')[['Sales','Discount','Profit']].mean()
df_segment
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %%
df_segment.plot.pie(subplots = True, labels = df_segment.index,figsize = (18,20),autopct = '%1.2f%%')
# Out:
# c:\users\kulkarni\appdata\local\programs\python\python38-32\lib\site-packages\pandas\plotting\_matplotlib\core.py:1547: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %% [markdown]
# #### Sales and Profit both are more in Home Office segment.
# #### discount is more in corporate.

# %% [markdown]
# ## Profit analyzation based on city

# %%
df['City'].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
df['City'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0             Henderson
# 1             Henderson
# 2           Los Angeles
# 3       Fort Lauderdale
# 4       Fort Lauderdale
#              ...
# 9989              Miami
# 9990         Costa Mesa
# 9991         Costa Mesa
# 9992         Costa Mesa
# 9993        Westminster
# Name: City, Length: 9994, dtype: object>

# %%
fig ,ax = plt.subplots(figsize = (30,8))
sns.countplot(df['City'].head(100),ax = ax)
# Out:
# c:\users\kulkarni\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
df_city = df.groupby('City')[['Sales','Discount','Profit']].mean()
df_city.head(10)
# Out:
#                   Sales  Discount     Profit
# City
# Aberdeen      25.500000  0.000000   6.630000
# Abilene        1.392000  0.800000  -3.758400
# Akron        129.999333  0.357143  -8.887410
# Albuquerque  158.582857  0.057143  45.292007
# Alexandria   344.973125  0.000000  19.913644
# Allen         72.551500  0.375000  -9.969375
# Allentown    121.893143  0.271429 -32.350057
# Altoona       10.225500  0.450000  -0.591750
# Amarillo     377.306280  0.272000 -38.796830
# Anaheim      295.810000  0.081481  45.703837

# %%
df_city.tail(10)
# Out:
#                  Sales  Discount      Profit
# City
# Wilmington  202.696139  0.080556   54.102831
# Wilson       61.455333  0.366667   -2.389333
# Woodbury    202.550000  0.000000   65.365400
# Woodland     88.220667  0.133333   11.128267
# Woodstock   228.780000  0.260000   15.998580
# Woonsocket   48.887500  0.000000   19.669775
# Yonkers     510.511067  0.066667  184.517047
# York        163.595600  0.420000  -20.433840
# Yucaipa      50.800000  0.000000   13.208000
# Yuma        210.216250  0.450000 -116.497725

# %%
#Sorting the cities with respect to profit in descending
df_city = df_city.sort_values('Profit',ascending = False)
#Top ten 10 Profit giving cities
df_city.head(10)
# Out:
#                     Sales  Discount      Profit
# City
# Jamestown     2354.395000  0.000000  642.885750
# Independence  1208.685000  0.000000  487.831500
# Lafayette      807.619355  0.000000  323.173794
# Minneapolis    733.501739  0.000000  296.721070
# Appleton       835.655000  0.000000  277.383150
# Morristown     719.014286  0.000000  262.603871
# Burbank       1082.386000  0.066667  254.844600
# Lehi           758.363000  0.100000  225.831300
# Beverly        861.063333  0.000000  218.306467
# Warwick        485.368000  0.000000  212.759120

# %%
#Least Profit giving cities
df_city.tail(10)
# Out:
#                   Sales  Discount      Profit
# City
# Yuma         210.216250  0.450000 -116.497725
# San Antonio  370.229288  0.383051 -123.712715
# Burlington   866.723280  0.136000 -144.915088
# Medina       275.302444  0.433333 -149.227178
# Clarksville  316.818571  0.271429 -150.764743
# Lancaster    215.031826  0.315217 -157.371052
# Round Rock   693.436114  0.274286 -169.061614
# Oswego       107.326000  0.600000 -178.709200
# Champaign    151.960000  0.600000 -182.352000
# Bethlehem    337.926800  0.380000 -200.619160

# %%
#Plot Profit,Discount ,sale of Top 30 cities
#df_city.head(30).plot(kind = 'bar',color = 'green',figsize= (18,20))
df_city['Profit'].head(30).plot(kind='bar',figsize=(15,5),color = 'Green')
plt.title('City wise analysis of  profit')
# Out:
# Text(0.5, 1.0, 'City wise analysis of  profit')

# %%
#Low Profit
df_city['Profit'].tail(30).plot(kind='bar',figsize=(15,5),color = 'Red')
plt.title('City wise analysis of profit')
# Out:
# Text(0.5, 1.0, 'City wise analysis of profit')

# %% [markdown]
# ## State wise analysis of Profit , Sales ,Discount

# %% [markdown]
# ### State wise analysis of Profit

# %%
df['State'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Kentucky
# 1         Kentucky
# 2       California
# 3          Florida
# 4          Florida
#            ...
# 9989       Florida
# 9990    California
# 9991    California
# 9992    California
# 9993    California
# Name: State, Length: 9994, dtype: object>

# %%
df['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
df_state = df.groupby('State')['Sales','Discount','Profit'].mean()
df_state.head()
# Out:
# <ipython-input-48-66202c5cff2e>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_state = df.groupby('State')['Sales','Discount','Profit'].mean()
#                  Sales  Discount     Profit
# State
# Alabama     319.846557  0.000000  94.865989
# Arizona     157.508933  0.303571 -15.303235
# Arkansas    194.635500  0.000000  66.811452
# California  228.729451  0.072764  38.171608
# Colorado    176.418231  0.316484 -35.867351

# %%
df_state.sort_values('Profit',ascending = False,inplace = True)

# %%
df_state.head(10)
# Out:
#                             Sales  Discount      Profit
# State
# Vermont                811.760909  0.000000  204.088936
# Rhode Island           404.070643  0.021429  130.100523
# Indiana                359.431946  0.000000  123.375411
# Montana                372.623467  0.066667  122.221900
# Minnesota              335.541011  0.000000  121.608847
# District of Columbia   286.502000  0.000000  105.958930
# Delaware               285.948635  0.006250  103.930988
# Wyoming               1603.136000  0.200000  100.196000
# Missouri               336.441667  0.000000   97.518341
# Michigan               299.096525  0.007059   95.934069

# %%
df_state[['Profit']].plot(kind = 'bar',figsize = (20,8))
plt.xlabel('Profit ')
plt.ylabel('Name of States')
plt.title('Profit vs States')
plt.legend()

# %% [markdown]
# #### Highest Profit giving city is "Vermont ".
# #### Lowest Profit giving city is "Ohio"

# %% [markdown]
# ## State wise analysis of sales

# %%
df_state[['Sales']].plot.pie(subplots = True,autopct = "%1.2f%%",figsize =(50,20),labels = df_state.index)
# Out:
# array([<AxesSubplot:ylabel='Sales'>], dtype=object)

# %% [markdown]
# ### Let plot graph of top h 30 ighest sales states

# %%
df_state1 = df_state.sort_values('Sales',ascending = False)

# %%
df_state1[['Sales']].head(30).plot(kind = 'bar',color = 'Pink',figsize = (20,8))
#df_state1[['Sales']].tail(30).plot(kind = 'bar',color = 'orange',figsize =(20,8))
plt.xlabel('States',fontsize = 15)
plt.ylabel('Sales')
plt.title('Plot of Top 30 Sales State',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Plot of Top 30 Sales State')

# %% [markdown]
# #### Highest sale : Wyoming

# %%
df_state1[['Sales']].tail(30).plot(kind = 'bar',color = 'orange',figsize = (20,8))
plt.title('Plot of least Sales State',fontsize = 20)
plt.xlabel('States',fontsize =15)
plt.ylabel('Sales',fontsize = 15)
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# #### Lowest sale : South Dakota

# %% [markdown]
# ### Discount analysis state wise

# %%
df_state1['Discount'].plot(kind='bar',figsize=(20,5))
plt.title('State wise analysis of Discount', fontsize=20)
plt.xlabel('State',fontsize = 15)
plt.ylabel('Discount',fontsize = 15)
# Out:
# Text(0, 0.5, 'Discount')

# %% [markdown]
# #### Highest Discount is in Illinois State

# %% [markdown]
# ## Category wise analysis of Profit

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df_category = df.groupby('Category')[['Sales','Discount','Profit']].mean()
df_category
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %%
df_category.plot.pie(subplots=True, 
                     figsize=(20, 20), 
                     autopct='%1.2f%%', 
                     labels = df_category.index)
# Out:
# c:\users\kulkarni\appdata\local\programs\python\python38-32\lib\site-packages\pandas\plotting\_matplotlib\core.py:1547: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %% [markdown]
# #### Highest Profit and Sales is in Technology

# %% [markdown]
# #### Though Furniture has 37.95% of total Sale its profit is too less.
# #### As highest amount of discount is given in furniture .(17.39%)

# %% [markdown]
# ## Subcategory wise Sales, Profit and Discount analysis

# %%
df_sub_category = df.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
df_sub_category.head(10)
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.068834  0.074874    8.200737
# Binders        133.560560  0.372292   19.843574
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.332420  0.170178   43.095894
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.825668  0.138349   13.645918

# %%
df_sub_category[['Sales','Discount']].plot(kind = 'pie', autopct = '%1.2f%%',figsize = (30,20),labels = df_sub_category.index,subplots = True)
# Out:
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>],
#       dtype=object)

# %% [markdown]
# #### Maximum sale is in Copiers , Machines ,Chairs respectively.
# #### Minimum sale is in art.

# %% [markdown]
# ####  Maximum discount on Binders, Machines and Tables

# %%
df_sub_category.sort_values('Profit')[['Sales','Profit']].plot(kind='bar',
                                                              figsize= (15,5),
                                                              label=['Average Sales Price','Profit'])
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# #### we should about discount on Tables , though having good sales of Table Profit is negative i.e not at all.
# #### also huge discount on Machines , so very less profit after large sales.

# %% [markdown]
# ## Profit analysis Region wise

# %%
df.Region.unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df_region = df.groupby('Region')['Sales','Profit','Discount'].mean()
df_region.head()
# Out:
# <ipython-input-74-4b582c44a9ae>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_region = df.groupby('Region')['Sales','Profit','Discount'].mean()
#               Sales     Profit  Discount
# Region
# Central  215.772661  17.092709  0.240353
# East     238.336110  32.135808  0.145365
# South    241.803645  28.857673  0.147253
# West     226.493233  33.849032  0.109335

# %%
df_region.plot(kind = 'pie',autopct = '%1.2f%%',subplots = True, figsize = (20,8),labels = df_region.index)
# Out:
# c:\users\kulkarni\appdata\local\programs\python\python38-32\lib\site-packages\pandas\plotting\_matplotlib\core.py:1547: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Profit'>,
#        <AxesSubplot:ylabel='Discount'>], dtype=object)

# %% [markdown]
# #### Sale is nearly same in all regions
# #### Profit is high in west as discount is least in west
# #### Profit is less in Central as discount is more in Central

# %% [markdown]
# # Summary

# %% [markdown]
# ### Profit is more than sales .
# ### Furniture has less profit mainly beacause of huge discount on Tables .
# ### So need to think about discount on tables

# %% [markdown]
# ### Quantity doesn't affect the profit , that means profit per item is not consistent.

# %% [markdown]
# #### state Ohio : Lowest Profit
# #### state Vermont : Highest profit
#
# ### out of Total profit , 73 % is from Technology .

# %% [markdown]
# #### Sales and Profit are Moderately Correlated.
# #### Quantity and Profit are less Moderately Correlated.
# #### Discount and Profit are Negatively Correlated
#
# Lowest amount of sales= South Dakota(0.8%)
